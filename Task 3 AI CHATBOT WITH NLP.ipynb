# %%
pip install nltk spacy
# Out:
# Requirement already satisfied: nltk in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.9.4)
# Requirement already satisfied: spacy in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.8.13)
# Requirement already satisfied: click in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (8.3.2)
# Requirement already satisfied: joblib in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (0.24.1)
# Requirement already satisfied: numpy>=1.19.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (2.13.1)
# Requirement already satisfied: jinja2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.1)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 5.7 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.8 MB 5.7 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 5.6 MB/s eta 0:00:02
#      ------------- -------------------------- 4.5/12.8 MB 5.5 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 5.5 MB/s eta 0:00:02
#      --------------------- ------------------ 6.8/12.8 MB 5.6 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 5.7 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 5.8 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 5.7 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 5.7 MB/s  0:00:02
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
from nltk.tokenize import word_tokenize
import random

# Download required NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')  # extra safety for newer versions

# Sample responses
responses = {
    "hello": ["Hi there!", "Hello!", "Hey!"],
    "how are you": ["I'm fine!", "Doing great!", "All good!"],
    "bye": ["Goodbye!", "See you!", "Bye!"]
}

def chatbot():
    print("Chatbot: Hello! Type 'bye' to exit.")
    
    while True:
        user_input = input("You: ").lower()

        # Tokenize input (safe)
        try:
            tokens = word_tokenize(user_input)
        except:
            tokens = user_input.split()

        found = False
        
        for key in responses:
            if key in user_input:
                print("Chatbot:", random.choice(responses[key]))
                found = True
                break
        
        if not found:
            print("Chatbot: Sorry, I don't understand.")

        if "bye" in user_input:
            break

# Run chatbot
chatbot()
# Out:
# Chatbot: Hello! Type 'bye' to exit.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# You:  how are you
# Chatbot: I'm fine!
# You:  ok bye
# Chatbot: See you!
